# %% [markdown]
# <a href="https://colab.research.google.com/github/hayatosc/experiment-codes/blob/main/2024/10/30/ELISA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.DataFrame(data={'index': ['Sample 1', 'Sample 2', 'Sample 3', 'Sample 4'], 'absorbance': [102.308, 202.973, 59.061, 1235.863]})
fig, ax = plt.subplots()
ax = sns.barplot(data=df, x='index', y='absorbance')
plt.show()
